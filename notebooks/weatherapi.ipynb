# %%
city = "Louisville"
baseurl = "http://api.weatherapi.com/v1"
jayson_key = "YOUR_API_KEY"

#key=<your own key>

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=Louisville #

# %%
import requests
import pandas as pd

# %%
baseurl = f"http://api.weatherapi.com/v1/current.json?key={jayson_key}&q=Louisville"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1777400928,
#   'localtime': '2026-04-28 14:28'},
#  'current': {'last_updated_epoch': 1777400100,
#   'last_updated': '2026-04-28 14:15',
#   'temp_c': 23.3,
#   'temp_f': 73.9,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 9.2,
#   'wind_kph': 14.8,
#   'wind_degree': 269,
#   'wind_dir': 'W',
#   'pressure_mb': 1015.0,
#   'pressure_in': 29.97,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 71,
#   'cloud': 75,
#   'feelslike_c': 25.2,
#   'feelslike_f': 77.3,
#   'windchill_c': 22.8,
#   'windchill_f': 73.1,
#   'heatindex_c': 24.7,
#   'heatindex_f': 76.5,
#   'dewpoint_c': 17.4,
#   'dewpoint_f': 63.3,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
temp_c = current['temp_c']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
humidity
# Out:
# 71

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={jayson_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        temp_c = current['temp_c']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']},{location['region']}")
        print(f"Temperature: {current['temp_f']}°F / {current['temp_c']}°C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']}mph")
    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Cincinnati")
# Out:
# Weather for Cincinnati,Ohio
# Temperature: 73.0°F / 22.8°C
# Condition: Partly cloudy
# Humidity: 66%
# Wind Speed: 11.9mph

# %%
cities = ["Louisville", "Cincinnati", "Lexington", "New York", "Sacramento"]
weather_data = []

for city in cities:
    url = url = f"http://api.weatherapi.com/v1/current.json?key={jayson_key}&q={city}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']  })
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Louisville',
#   'Temperature': 75.0,
#   'Condition': 'Sunny',
#   'Humidity': 62,
#   'Wind Speed': 9.2},
#  {'City': 'Cincinnati',
#   'Temperature': 73.9,
#   'Condition': 'Partly cloudy',
#   'Humidity': 57,
#   'Wind Speed': 11.9},
#  {'City': 'Lexington-Fayette',
#   'Temperature': 75.6,
#   'Condition': 'Partly cloudy',
#   'Humidity': 65,
#   'Wind Speed': 12.8},
#  {'City': 'New York',
#   'Temperature': 62.1,
#   'Condition': 'Sunny',
#   'Humidity': 39,
#   'Wind Speed': 10.5},
#  {'City': 'Sacramento',
#   'Temperature': 66.9,
#   'Condition': 'Sunny',
#   'Humidity': 49,
#   'Wind Speed': 3.8}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#                 City  Temperature      Condition  Humidity  Wind Speed
# 0         Louisville         75.0          Sunny        62         9.2
# 1         Cincinnati         73.9  Partly cloudy        57        11.9
# 2  Lexington-Fayette         75.6  Partly cloudy        65        12.8
# 3           New York         62.1          Sunny        39        10.5
# 4         Sacramento         66.9          Sunny        49         3.8

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
